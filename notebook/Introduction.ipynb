# %%
import meta

# %%
imagenet = meta.load('imagenet/image:val')

# %%
imagenet.shape
# Out:
# Vec(50000,375,500,3, dtype=int64)

# %%
imagenet[0].mean()
# Out:
# VolumeCutout(113.39153067)

# %% [markdown]
# ### Plot image

# %%
import matplotlib.pyplot as plt

# %%
imgplot = plt.imshow(imagenet[10000][0])
